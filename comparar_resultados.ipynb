# %%
import pandas as pd 
import numpy as np

# %%
#df = pd.read_csv('documentos/resultados/redenciones_fs.csv', sep=';')
#df_resultados = pd.read_csv('documentos/resultados/redenciones_fs.csv', sep=';', encoding='ISO-8859-1')

df = pd.read_excel('documentos/redenciones/cp_redenciones.xlsx', sheet_name='Casos de Prueba')

# %%
df.head(30)
# Out:
#       Casos de Prueba                              Unnamed: 1  \
# 0                 NaN                                     NaN
# 1          Proyecto:                                Redencion
# 2   Ciclo de Pruebas:                                       1
# 3                 NaN                                     NaN
# 4                  ID                          Caso de Prueba
# 5                   1           Redencion Mantenedor -Exitoso
# 6                   2  Redencion Mantenedor reportes -Exitoso
# 7                   3                 Redencion APP - Exitoso
# 8                 NaN                                     NaN
# 9                 NaN                                     NaN
# 10                NaN                                     NaN
# 11                NaN                                     NaN
# 12                NaN                                     NaN
# 13                NaN                                     NaN
#
# ...

# %%
subset = df.iloc[5:8]
subset1 = subset[['Unnamed: 2', 'Unnamed: 7']]
# Supongamos que df es tu DataFrame y que quieres cambiar el nombre de 'Unnamed: 2' a 'nuevo_nombre1' y 'Unnamed: 7' a 'nuevo_nombre2'
# Out:
#                                           Unnamed: 2  \
# 5  Se ingresa al mantenedor con el usuario NBA en...
# 6  Se ingresa al mantenedor con el usuario NBA en...
# 7  Se ingresa a la aplicacon con el DN 5537685200...
#
#                                          Unnamed: 7
# 5  Se crea bloque, categoria y beneficio con éxito.
# 6                      Geracion de reporte exitoso
# 7                       Flujo de redecnion exitoso

# %%
subset2 = subset1.rename(columns={'Unnamed: 2': 'caso de prueba', 'Unnamed: 7': 'resultado esperado'})
subset2
# Out:
#                                       caso de prueba  \
# 5  Se ingresa al mantenedor con el usuario NBA en...
# 6  Se ingresa al mantenedor con el usuario NBA en...
# 7  Se ingresa a la aplicacon con el DN 5537685200...
#
#                                  resultado esperado
# 5  Se crea bloque, categoria y beneficio con éxito.
# 6                      Geracion de reporte exitoso
# 7                       Flujo de redecnion exitoso

# %%
subset2.to_csv('casos_de_prueba.csv', index=False)

# %%
import libs.check_encoding

check_encoding.check_encoding('documentos/redenciones/cp_redenciones.xlsx')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 import libs.check_encoding
# ----> 3 check_encoding.check_encoding('documentos/redenciones/cp_redenciones.xlsx')
#
# NameError: name 'check_encoding' is not defined

# %%
import convert_excel_to_csv

convert_excel_to_csv.convert_excel_to_csv('documentos/redenciones/cp_redenciones.xlsx', 'documentos/redenciones/cp_redenciones.csv')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import convert_excel_to_csv
#       3 convert_excel_to_csv.convert_excel_to_csv('documentos/redenciones/cp_redenciones.xlsx', 'documentos/redenciones/cp_redenciones.csv')
#
# ModuleNotFoundError: No module named 'convert_excel_to_csv'
